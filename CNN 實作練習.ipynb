# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter

from PIL import Image, ImageOps

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
resize = 200
batch_size = 64
data_dir = 'data'

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(resize),
        transforms.RandomResizedCrop(resize),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'validation': transforms.Compose([
        transforms.Resize(resize),
        transforms.CenterCrop(resize),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(resize),
        transforms.CenterCrop(resize),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
    for x in ['train', 'validation', 'test']}

dataloaders = {x: DataLoader(image_datasets[x],
                             batch_size=batch_size,
                             shuffle=(x == 'train'),
                             num_workers=4)
               for x in ['train', 'validation', 'test']}

class_names = image_datasets["test"].classes

# %%
class NeuralNetwork(nn.Module):

    def __init__(self):
        super().__init__()

        self.cnn1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=5, stride=1, padding=2)  #output_shape=(16,200,200)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)  #output_shape=(16,100,100)

        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2) #output_shape=(32,100,100)
        self.relu2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)  #output_shape=(32,50,50)

        self.cnn3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2)  #output_shape=(64,50,50)
        self.relu3 = nn.ReLU()
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)  #output_shape=(64,25,25)
        # Fully connected 1                          #input_shape=(64 * 25 * 25)
        self.fc1 = nn.Linear(64 * 25 * 25, 3)

    def forward(self, x):

        x = self.cnn1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)

        x = self.cnn2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)

        x = self.cnn3(x)
        x = self.relu3(x)
        x = self.maxpool3(x)

        x = x.view(x.size(0), -1)

        x = self.fc1(x)

        return x

# %%
model = NeuralNetwork().to(device)
print(model)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
#optimizer = torch.optim.RMSprop(model.parameters(), 0.01, alpha=0.9)
#optimizer = torch.optim.Adam(model.parameters(), 0.01, betas=(0.9, 0.99))
# Out:
# NeuralNetwork(
#   (cnn1): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu1): ReLU()
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu2): ReLU()
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu3): ReLU()
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=40000, out_features=3, bias=True)
# )

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()

    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # X = X.flatten(start_dim=1)
        X, y = X.to(device), y.to(device)
        pred = model(X)
        loss = loss_fn(pred, y)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 10 == 0:
            loss, current = loss.item(), (batch + 1) * len(X) #len(X) = batch_size 64
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

        train_loss += loss_fn(pred, y).item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    train_loss /= size
    correct /= size

    train_losses.append(train_loss)
    train_acc.append(correct)

    # writer.add_scalar('Loss/Train', train_loss, t)
    # writer.add_scalar('Accuracy/Train', correct, t)

    writer.add_scalars(main_tag='Loss', tag_scalar_dict={'Train Loss': train_loss}, global_step=t)
    writer.add_scalars(main_tag='Accuracy', tag_scalar_dict={'Train Accuracy': correct}, global_step=t)

    print(f"train accuracy:\t\t{(100*correct):>0.1f}%, train loss:\t\t{train_loss:>4f}")


def validation(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    model.eval()

    validation_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            # X = X.flatten(start_dim=1)
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)

            validation_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    validation_loss /= size
    correct /= size

    validation_losses.append(validation_loss)
    validation_acc.append(correct)

    # writer.add_scalar('Loss/Test', test_loss, t)
    # writer.add_scalar('Accuracy/Test', correct, t)

    writer.add_scalars(main_tag='Loss', tag_scalar_dict={'Validation Loss': validation_loss}, global_step=t)
    writer.add_scalars(main_tag='Accuracy', tag_scalar_dict={'Validation Accuracy': correct}, global_step=t)

    print(f"validation accuracy:\t{(100*correct):>0.1f}%, validation loss:\t\t{validation_loss:>4f}")


def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    model.eval()

    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            # X = X.flatten(start_dim=1)
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)

            test_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= size
    correct /= size

    print(f"test accuracy:\t\t{(100*correct):>0.1f}%, test loss:\t\t{test_loss:>4f}")


def test_with_confusion(dataloader, model, loss_fn, class_names):
    size = len(dataloader.dataset)
    model.eval()

    test_loss, correct = 0, 0
    all_preds = []
    all_y = []

    with torch.no_grad():
        for X, y in dataloader:
            # X = X.flatten(start_dim=1)
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)

            test_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            all_preds.extend(pred.argmax(1).cpu().numpy())
            all_y.extend(y.cpu().numpy())

    test_loss /= size
    correct /= size

    # 計算混淆矩陣
    cm = confusion_matrix(all_y, all_preds)

    # 繪製熱力圖
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

    return correct, test_loss, cm

def show_misclassified_images(dataloader, model, class_names, max_images=10):

    model.to(device)
    model.eval()

    misclassified_images = []
    y_labels = []
    pred_labels = []

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            loss = loss_fn(pred, y)
            predict = pred.argmax(1)

            for img, label, predict_class in zip(X, y, predict):
                if label != predict_class:  
                    misclassified_images.append(img.cpu())
                    y_labels.append(class_names[label.item()])
                    pred_labels.append(class_names[predict_class.item()])

                if len(misclassified_images) >= max_images:
                    break
            if len(misclassified_images) >= max_images:
                break

    plt.figure(figsize=(12, 6))
    for i in range(len(misclassified_images)):
        plt.subplot(2, (max_images+1)//2, i+1)
        img = misclassified_images[i].permute(1, 2, 0)  # [C,H,W] → [H,W,C]
        img = (img * 0.5 + 0.5).clamp(0,1)  # 還原 Normalize
        plt.imshow(img)
        plt.title(f"label: {y_labels[i]}\npredict: {pred_labels[i]}", fontsize=10)
        plt.axis("off")
    plt.tight_layout()
    plt.show()


def predict_image(path, model, class_names):
   
    model.to(device)
    model.eval()

    image = Image.open(path).convert("RGB")
    transform = transforms.Compose([
        transforms.Resize(resize),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    image = transform(image).unsqueeze(0).to(device) 

    with torch.no_grad():
        pred = model(image)
        predict = pred.argmax(1).cpu().numpy()
    predict_class = class_names[predict.item()]
    
    return predict_class

# %%
acc_loss_dir = 'runs/acc_loss'
epochs = 300
train_losses = []
train_acc = []
validation_losses = []
validation_acc = []
writer = SummaryWriter(acc_loss_dir)
for t in range(epochs):
    print(f"\nEpoch {t+1}\n-------------------------------")
    train(dataloaders["train"], model, loss_fn, optimizer)
    validation(dataloaders["validation"], model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.086859  [   64/  750]
# loss: 1.067648  [  704/  750]
# train accuracy:		35.7%, train loss:		0.017200
# validation accuracy:	33.3%, validation loss:		0.021847
#
# Epoch 2
# -------------------------------
# loss: 1.041558  [   64/  750]
# loss: 1.008462  [  704/  750]
# train accuracy:		32.5%, train loss:		0.016744
# validation accuracy:	33.3%, validation loss:		0.021865
#
# Epoch 3
# -------------------------------
# loss: 1.060406  [   64/  750]
# loss: 1.007423  [  704/  750]
# train accuracy:		33.2%, train loss:		0.016526
# validation accuracy:	33.3%, validation loss:		0.021830
#
# Epoch 4
# -------------------------------
# loss: 1.012943  [   64/  750]
# loss: 1.049488  [  704/  750]
# train accuracy:		35.1%, train loss:		0.016372
# validation accuracy:	33.3%, validation loss:		0.021721
#
# Epoch 5
# -------------------------------
# loss: 1.001101  [   64/  750]
# loss: 0.986776  [  704/  750]
# train accuracy:		36.5%, train loss:		0.016082
# validation accuracy:	36.7%, validation loss:		0.021624
#
# Epoch 6
# -------------------------------
# loss: 0.979284  [   64/  750]
# loss: 1.040018  [  704/  750]
# train accuracy:		49.7%, train loss:		0.015942
# validation accuracy:	35.3%, validation loss:		0.021509
#
# Epoch 7
# -------------------------------
# loss: 0.953324  [   64/  750]
# loss: 0.995819  [  704/  750]
# train accuracy:		45.2%, train loss:		0.015788
# validation accuracy:	50.7%, validation loss:		0.021290
#
# Epoch 8
# -------------------------------
# loss: 0.990810  [   64/  750]
# loss: 1.002546  [  704/  750]
# train accuracy:		58.9%, train loss:		0.015539
# validation accuracy:	40.7%, validation loss:		0.021174
#
# Epoch 9
# -------------------------------
# loss: 0.948486  [   64/  750]
# loss: 0.973332  [  704/  750]
# train accuracy:		50.9%, train loss:		0.015440
# validation accuracy:	44.0%, validation loss:		0.021011
#
# Epoch 10
# -------------------------------
# loss: 0.950526  [   64/  750]
# loss: 0.924293  [  704/  750]
# train accuracy:		54.1%, train loss:		0.015199
# validation accuracy:	49.3%, validation loss:		0.020872
#
# Epoch 11
# -------------------------------
# loss: 0.926824  [   64/  750]
# loss: 0.962705  [  704/  750]
# train accuracy:		56.1%, train loss:		0.015036
# validation accuracy:	50.0%, validation loss:		0.020668
#
# Epoch 12
# -------------------------------
# loss: 0.869776  [   64/  750]
# loss: 0.900998  [  704/  750]
# train accuracy:		61.7%, train loss:		0.014825
# validation accuracy:	52.0%, validation loss:		0.020499
#
# Epoch 13
# -------------------------------
# loss: 0.837059  [   64/  750]
# loss: 1.018394  [  704/  750]
# train accuracy:		57.3%, train loss:		0.014661
# validation accuracy:	63.3%, validation loss:		0.020307
#
# Epoch 14
# -------------------------------
# loss: 0.894644  [   64/  750]
# loss: 0.892981  [  704/  750]
# train accuracy:		63.9%, train loss:		0.014532
# validation accuracy:	62.7%, validation loss:		0.020073
#
# Epoch 15
# -------------------------------
# loss: 0.867993  [   64/  750]
# loss: 0.958663  [  704/  750]
# train accuracy:		62.4%, train loss:		0.014452
# validation accuracy:	64.0%, validation loss:		0.019936
#
# Epoch 16
# -------------------------------
# loss: 0.926858  [   64/  750]
# loss: 0.907550  [  704/  750]
# train accuracy:		64.5%, train loss:		0.014321
# validation accuracy:	62.7%, validation loss:		0.019888
#
# Epoch 17
# -------------------------------
# loss: 0.867917  [   64/  750]
# loss: 0.940079  [  704/  750]
# train accuracy:		66.8%, train loss:		0.014159
# validation accuracy:	68.7%, validation loss:		0.019682
#
# Epoch 18
# -------------------------------
# loss: 0.814671  [   64/  750]
# loss: 0.816975  [  704/  750]
# train accuracy:		66.1%, train loss:		0.014083
# validation accuracy:	70.7%, validation loss:		0.019571
#
# Epoch 19
# -------------------------------
# loss: 0.881529  [   64/  750]
# loss: 0.831738  [  704/  750]
# train accuracy:		66.9%, train loss:		0.013956
# validation accuracy:	71.3%, validation loss:		0.019424
#
# Epoch 20
# -------------------------------
# loss: 0.898580  [   64/  750]
# loss: 0.793320  [  704/  750]
# train accuracy:		67.9%, train loss:		0.013941
# validation accuracy:	60.0%, validation loss:		0.019344
#
# Epoch 21
# -------------------------------
# loss: 0.950536  [   64/  750]
# loss: 0.902879  [  704/  750]
# train accuracy:		69.1%, train loss:		0.013902
# validation accuracy:	72.7%, validation loss:		0.018944
#
# Epoch 22
# -------------------------------
# loss: 0.848184  [   64/  750]
# loss: 0.870672  [  704/  750]
# train accuracy:		70.1%, train loss:		0.013772
# validation accuracy:	73.3%, validation loss:		0.018721
#
# Epoch 23
# -------------------------------
# loss: 0.858313  [   64/  750]
# loss: 0.904098  [  704/  750]
# train accuracy:		69.5%, train loss:		0.013625
# validation accuracy:	72.0%, validation loss:		0.018529
#
# Epoch 24
# -------------------------------
# loss: 0.787219  [   64/  750]
# loss: 0.830175  [  704/  750]
# train accuracy:		71.9%, train loss:		0.013562
# validation accuracy:	74.7%, validation loss:		0.018344
#
# Epoch 25
# -------------------------------
# loss: 0.883034  [   64/  750]
# loss: 0.849259  [  704/  750]
# train accuracy:		73.6%, train loss:		0.013303
# validation accuracy:	74.7%, validation loss:		0.018251
#
# Epoch 26
# -------------------------------
# loss: 0.763215  [   64/  750]
# loss: 0.830363  [  704/  750]
# train accuracy:		71.3%, train loss:		0.013090
# validation accuracy:	74.7%, validation loss:		0.017986
#
# Epoch 27
# -------------------------------
# loss: 0.732249  [   64/  750]
# loss: 0.793113  [  704/  750]
# train accuracy:		72.9%, train loss:		0.013062
# validation accuracy:	75.3%, validation loss:		0.017756
#
# Epoch 28
# -------------------------------
# loss: 0.976029  [   64/  750]
# loss: 0.887532  [  704/  750]
# train accuracy:		73.3%, train loss:		0.012975
# validation accuracy:	76.0%, validation loss:		0.017565
#
# Epoch 29
# -------------------------------
# loss: 0.732038  [   64/  750]
# loss: 0.780692  [  704/  750]
# train accuracy:		73.2%, train loss:		0.012860
# validation accuracy:	70.0%, validation loss:		0.017225
#
# Epoch 30
# -------------------------------
# loss: 0.886585  [   64/  750]
# loss: 0.723324  [  704/  750]
# train accuracy:		73.1%, train loss:		0.012613
# validation accuracy:	77.3%, validation loss:		0.016914
#
# Epoch 31
# -------------------------------
# loss: 0.809795  [   64/  750]
# loss: 0.739212  [  704/  750]
# train accuracy:		72.1%, train loss:		0.012596
# validation accuracy:	77.3%, validation loss:		0.016772
#
# Epoch 32
# -------------------------------
# loss: 0.796409  [   64/  750]
# loss: 0.847155  [  704/  750]
# train accuracy:		74.4%, train loss:		0.012092
# validation accuracy:	74.7%, validation loss:		0.016648
#
# Epoch 33
# -------------------------------
# loss: 0.701761  [   64/  750]
# loss: 0.820467  [  704/  750]
# train accuracy:		74.4%, train loss:		0.011965
# validation accuracy:	74.7%, validation loss:		0.016469
#
# Epoch 34
# -------------------------------
# loss: 0.769479  [   64/  750]
# loss: 0.636461  [  704/  750]
# train accuracy:		72.5%, train loss:		0.012029
# validation accuracy:	69.3%, validation loss:		0.016609
#
# Epoch 35
# -------------------------------
# loss: 0.777402  [   64/  750]
# loss: 0.735731  [  704/  750]
# train accuracy:		73.2%, train loss:		0.011730
# validation accuracy:	72.0%, validation loss:		0.016500
#
# Epoch 36
# -------------------------------
# loss: 0.693156  [   64/  750]
# loss: 0.688851  [  704/  750]
# train accuracy:		74.4%, train loss:		0.011553
# validation accuracy:	77.3%, validation loss:		0.015881
#
# Epoch 37
# -------------------------------
# loss: 0.793053  [   64/  750]
# loss: 0.680742  [  704/  750]
# train accuracy:		74.0%, train loss:		0.011495
# validation accuracy:	73.3%, validation loss:		0.015802
#
# Epoch 38
# -------------------------------
# loss: 0.652325  [   64/  750]
# loss: 0.746759  [  704/  750]
# train accuracy:		72.5%, train loss:		0.011373
# validation accuracy:	68.7%, validation loss:		0.016040
#
# Epoch 39
# -------------------------------
# loss: 0.828605  [   64/  750]
# loss: 0.750814  [  704/  750]
# train accuracy:		71.2%, train loss:		0.011568
# validation accuracy:	75.3%, validation loss:		0.015396
#
# Epoch 40
# -------------------------------
# loss: 0.705951  [   64/  750]
# loss: 0.701115  [  704/  750]
# train accuracy:		71.2%, train loss:		0.011484
# validation accuracy:	72.0%, validation loss:		0.015377
#
# Epoch 41
# -------------------------------
# loss: 0.693748  [   64/  750]
# loss: 0.636732  [  704/  750]
# train accuracy:		73.3%, train loss:		0.011134
# validation accuracy:	76.0%, validation loss:		0.015107
#
# Epoch 42
# -------------------------------
# loss: 0.790382  [   64/  750]
# loss: 0.676222  [  704/  750]
# train accuracy:		73.7%, train loss:		0.010806
# validation accuracy:	66.0%, validation loss:		0.015785
#
# Epoch 43
# -------------------------------
# loss: 0.761529  [   64/  750]
# loss: 0.668763  [  704/  750]
# train accuracy:		70.8%, train loss:		0.011159
# validation accuracy:	76.0%, validation loss:		0.015364
#
# Epoch 44
# -------------------------------
# loss: 0.765123  [   64/  750]
# loss: 0.731816  [  704/  750]
# train accuracy:		72.1%, train loss:		0.011042
# validation accuracy:	74.7%, validation loss:		0.015147
#
# Epoch 45
# -------------------------------
# loss: 0.772231  [   64/  750]
# loss: 0.701245  [  704/  750]
# train accuracy:		72.1%, train loss:		0.011049
# validation accuracy:	73.3%, validation loss:		0.015072
#
# Epoch 46
# -------------------------------
# loss: 0.708948  [   64/  750]
# loss: 0.713178  [  704/  750]
# train accuracy:		73.2%, train loss:		0.010765
# validation accuracy:	78.0%, validation loss:		0.014750
#
# Epoch 47
# -------------------------------
# loss: 0.746509  [   64/  750]
# loss: 0.736082  [  704/  750]
# train accuracy:		73.7%, train loss:		0.010703
# validation accuracy:	63.3%, validation loss:		0.015900
#
# Epoch 48
# -------------------------------
# loss: 0.581720  [   64/  750]
# loss: 0.614791  [  704/  750]
# train accuracy:		71.3%, train loss:		0.011067
# validation accuracy:	74.0%, validation loss:		0.014518
#
# Epoch 49
# -------------------------------
# loss: 0.587964  [   64/  750]
# loss: 0.679310  [  704/  750]
# train accuracy:		72.4%, train loss:		0.010606
# validation accuracy:	77.3%, validation loss:		0.014473
#
# Epoch 50
# -------------------------------
# loss: 0.704034  [   64/  750]
# loss: 0.611287  [  704/  750]
# train accuracy:		71.2%, train loss:		0.010856
# validation accuracy:	76.7%, validation loss:		0.014092
#
# Epoch 51
# -------------------------------
# loss: 0.630706  [   64/  750]
# loss: 0.663505  [  704/  750]
# train accuracy:		71.7%, train loss:		0.010661
# validation accuracy:	74.7%, validation loss:		0.014397
#
# Epoch 52
# -------------------------------
# loss: 0.581450  [   64/  750]
# loss: 0.562844  [  704/  750]
# train accuracy:		73.1%, train loss:		0.010656
# validation accuracy:	71.3%, validation loss:		0.014963
#
# Epoch 53
# -------------------------------
# loss: 0.688865  [   64/  750]
# loss: 0.702833  [  704/  750]
# train accuracy:		70.5%, train loss:		0.010847
# validation accuracy:	74.0%, validation loss:		0.014351
#
# Epoch 54
# -------------------------------
# loss: 0.656333  [   64/  750]
# loss: 0.650093  [  704/  750]
# train accuracy:		72.7%, train loss:		0.010432
# validation accuracy:	80.0%, validation loss:		0.013859
#
# Epoch 55
# -------------------------------
# loss: 0.586123  [   64/  750]
# loss: 0.644919  [  704/  750]
# train accuracy:		72.7%, train loss:		0.010443
# validation accuracy:	76.7%, validation loss:		0.014174
#
# Epoch 56
# -------------------------------
# loss: 0.521489  [   64/  750]
# loss: 0.611349  [  704/  750]
# train accuracy:		72.9%, train loss:		0.010211
# validation accuracy:	72.0%, validation loss:		0.014544
#
# Epoch 57
# -------------------------------
# loss: 0.705109  [   64/  750]
# loss: 0.569674  [  704/  750]
# train accuracy:		70.3%, train loss:		0.010659
# validation accuracy:	70.0%, validation loss:		0.014680
#
# Epoch 58
# -------------------------------
# loss: 0.626308  [   64/  750]
# loss: 0.649025  [  704/  750]
# train accuracy:		72.4%, train loss:		0.010480
# validation accuracy:	74.7%, validation loss:		0.014021
#
# Epoch 59
# -------------------------------
# loss: 0.657026  [   64/  750]
# loss: 0.707067  [  704/  750]
# train accuracy:		72.3%, train loss:		0.010506
# validation accuracy:	70.0%, validation loss:		0.014973
#
# Epoch 60
# -------------------------------
# loss: 0.617439  [   64/  750]
# loss: 0.605986  [  704/  750]
# train accuracy:		73.1%, train loss:		0.010517
# validation accuracy:	76.7%, validation loss:		0.013330
#
# Epoch 61
# -------------------------------
# loss: 0.750526  [   64/  750]
# loss: 0.722756  [  704/  750]
# train accuracy:		75.2%, train loss:		0.009913
# validation accuracy:	80.0%, validation loss:		0.012977
#
# Epoch 62
# -------------------------------
# loss: 0.628090  [   64/  750]
# loss: 0.545905  [  704/  750]
# train accuracy:		73.6%, train loss:		0.010103
# validation accuracy:	77.3%, validation loss:		0.013545
#
# Epoch 63
# -------------------------------
# loss: 0.673264  [   64/  750]
# loss: 0.480446  [  704/  750]
# train accuracy:		73.9%, train loss:		0.010301
# validation accuracy:	76.0%, validation loss:		0.013920
#
# Epoch 64
# -------------------------------
# loss: 0.707301  [   64/  750]
# loss: 0.633600  [  704/  750]
# train accuracy:		73.3%, train loss:		0.009918
# validation accuracy:	74.0%, validation loss:		0.014050
#
# Epoch 65
# -------------------------------
# loss: 0.677646  [   64/  750]
# loss: 0.640286  [  704/  750]
# train accuracy:		74.9%, train loss:		0.009973
# validation accuracy:	72.7%, validation loss:		0.014241
#
# Epoch 66
# -------------------------------
# loss: 0.609328  [   64/  750]
# loss: 0.611275  [  704/  750]
# train accuracy:		73.6%, train loss:		0.009948
# validation accuracy:	70.7%, validation loss:		0.014299
#
# Epoch 67
# -------------------------------
# loss: 0.571737  [   64/  750]
# loss: 0.573602  [  704/  750]
# train accuracy:		73.6%, train loss:		0.010072
# validation accuracy:	79.3%, validation loss:		0.013509
#
# Epoch 68
# -------------------------------
# loss: 0.774640  [   64/  750]
# loss: 0.769935  [  704/  750]
# train accuracy:		70.7%, train loss:		0.010148
# validation accuracy:	81.3%, validation loss:		0.012821
#
# Epoch 69
# -------------------------------
# loss: 0.475856  [   64/  750]
# loss: 0.662113  [  704/  750]
# train accuracy:		74.9%, train loss:		0.009755
# validation accuracy:	82.0%, validation loss:		0.012360
#
# Epoch 70
# -------------------------------
# loss: 0.455166  [   64/  750]
# loss: 0.543956  [  704/  750]
# train accuracy:		73.9%, train loss:		0.009730
# validation accuracy:	83.3%, validation loss:		0.012212
#
# Epoch 71
# -------------------------------
# loss: 0.691275  [   64/  750]
# loss: 0.685366  [  704/  750]
# train accuracy:		75.7%, train loss:		0.009926
# validation accuracy:	76.7%, validation loss:		0.012917
#
# Epoch 72
# -------------------------------
# loss: 0.589050  [   64/  750]
# loss: 0.670604  [  704/  750]
# train accuracy:		73.9%, train loss:		0.009639
# validation accuracy:	77.3%, validation loss:		0.012877
#
# Epoch 73
# -------------------------------
# loss: 0.570239  [   64/  750]
# loss: 0.509354  [  704/  750]
# train accuracy:		75.7%, train loss:		0.009820
# validation accuracy:	67.3%, validation loss:		0.014388
#
# Epoch 74
# -------------------------------
# loss: 0.585295  [   64/  750]
# loss: 0.703451  [  704/  750]
# train accuracy:		77.2%, train loss:		0.009697
# validation accuracy:	80.7%, validation loss:		0.012282
#
# Epoch 75
# -------------------------------
# loss: 0.605449  [   64/  750]
# loss: 0.476756  [  704/  750]
# train accuracy:		73.5%, train loss:		0.009628
# validation accuracy:	81.3%, validation loss:		0.011405
#
# Epoch 76
# -------------------------------
# loss: 0.606302  [   64/  750]
# loss: 0.625703  [  704/  750]
# train accuracy:		76.7%, train loss:		0.009466
# validation accuracy:	76.0%, validation loss:		0.012602
#
# Epoch 77
# -------------------------------
# loss: 0.657237  [   64/  750]
# loss: 0.740633  [  704/  750]
# train accuracy:		75.1%, train loss:		0.009198
# validation accuracy:	75.3%, validation loss:		0.013144
#
# Epoch 78
# -------------------------------
# loss: 0.435405  [   64/  750]
# loss: 0.626189  [  704/  750]
# train accuracy:		76.1%, train loss:		0.009142
# validation accuracy:	76.7%, validation loss:		0.011961
#
# Epoch 79
# -------------------------------
# loss: 0.608513  [   64/  750]
# loss: 0.620002  [  704/  750]
# train accuracy:		76.8%, train loss:		0.009424
# validation accuracy:	74.0%, validation loss:		0.012699
#
# Epoch 80
# -------------------------------
# loss: 0.554791  [   64/  750]
# loss: 0.522241  [  704/  750]
# train accuracy:		75.3%, train loss:		0.009543
# validation accuracy:	73.3%, validation loss:		0.012263
#
# Epoch 81
# -------------------------------
# loss: 0.576546  [   64/  750]
# loss: 0.630098  [  704/  750]
# train accuracy:		75.5%, train loss:		0.009020
# validation accuracy:	75.3%, validation loss:		0.012439
#
# Epoch 82
# -------------------------------
# loss: 0.573980  [   64/  750]
# loss: 0.567166  [  704/  750]
# train accuracy:		76.0%, train loss:		0.009079
# validation accuracy:	72.0%, validation loss:		0.012145
#
# Epoch 83
# -------------------------------
# loss: 0.680419  [   64/  750]
# loss: 0.483533  [  704/  750]
# train accuracy:		74.4%, train loss:		0.009220
# validation accuracy:	79.3%, validation loss:		0.011266
#
# Epoch 84
# -------------------------------
# loss: 0.466107  [   64/  750]
# loss: 0.633448  [  704/  750]
# train accuracy:		76.4%, train loss:		0.008719
# validation accuracy:	81.3%, validation loss:		0.011469
#
# Epoch 85
# -------------------------------
# loss: 0.475869  [   64/  750]
# loss: 0.444524  [  704/  750]
# train accuracy:		78.1%, train loss:		0.008557
# validation accuracy:	74.0%, validation loss:		0.012694
#
# Epoch 86
# -------------------------------
# loss: 0.491034  [   64/  750]
# loss: 0.676711  [  704/  750]
# train accuracy:		77.9%, train loss:		0.008796
# validation accuracy:	76.7%, validation loss:		0.011088
#
# Epoch 87
# -------------------------------
# loss: 0.520982  [   64/  750]
# loss: 0.679154  [  704/  750]
# train accuracy:		79.9%, train loss:		0.008526
# validation accuracy:	81.3%, validation loss:		0.010053
#
# Epoch 88
# -------------------------------
# loss: 0.599186  [   64/  750]
# loss: 0.496799  [  704/  750]
# train accuracy:		78.0%, train loss:		0.008971
# validation accuracy:	78.7%, validation loss:		0.010927
#
# Epoch 89
# -------------------------------
# loss: 0.569920  [   64/  750]
# loss: 0.613838  [  704/  750]
# train accuracy:		78.7%, train loss:		0.008563
# validation accuracy:	78.7%, validation loss:		0.010343
#
# Epoch 90
# -------------------------------
# loss: 0.482044  [   64/  750]
# loss: 0.599515  [  704/  750]
# train accuracy:		80.0%, train loss:		0.008178
# validation accuracy:	80.7%, validation loss:		0.010971
#
# Epoch 91
# -------------------------------
# loss: 0.481556  [   64/  750]
# loss: 0.495690  [  704/  750]
# train accuracy:		78.9%, train loss:		0.008680
# validation accuracy:	80.7%, validation loss:		0.010053
#
# Epoch 92
# -------------------------------
# loss: 0.533958  [   64/  750]
# loss: 0.654230  [  704/  750]
# train accuracy:		79.5%, train loss:		0.008350
# validation accuracy:	80.7%, validation loss:		0.009546
#
# Epoch 93
# -------------------------------
# loss: 0.534354  [   64/  750]
# loss: 0.375024  [  704/  750]
# train accuracy:		81.7%, train loss:		0.007948
# validation accuracy:	78.0%, validation loss:		0.010115
#
# Epoch 94
# -------------------------------
# loss: 0.551934  [   64/  750]
# loss: 0.438186  [  704/  750]
# train accuracy:		81.3%, train loss:		0.007748
# validation accuracy:	82.0%, validation loss:		0.009677
#
# Epoch 95
# -------------------------------
# loss: 0.398623  [   64/  750]
# loss: 0.410292  [  704/  750]
# train accuracy:		81.7%, train loss:		0.007973
# validation accuracy:	82.0%, validation loss:		0.009890
#
# Epoch 96
# -------------------------------
# loss: 0.526652  [   64/  750]
# loss: 0.608533  [  704/  750]
# train accuracy:		82.9%, train loss:		0.007678
# validation accuracy:	80.0%, validation loss:		0.009858
#
# Epoch 97
# -------------------------------
# loss: 0.497833  [   64/  750]
# loss: 0.460291  [  704/  750]
# train accuracy:		81.7%, train loss:		0.007868
# validation accuracy:	80.7%, validation loss:		0.010319
#
# Epoch 98
# -------------------------------
# loss: 0.386993  [   64/  750]
# loss: 0.478930  [  704/  750]
# train accuracy:		81.9%, train loss:		0.008055
# validation accuracy:	87.3%, validation loss:		0.008777
#
# Epoch 99
# -------------------------------
# loss: 0.439133  [   64/  750]
# loss: 0.388246  [  704/  750]
# train accuracy:		82.3%, train loss:		0.007737
# validation accuracy:	81.3%, validation loss:		0.009059
#
# Epoch 100
# -------------------------------
# loss: 0.360759  [   64/  750]
# loss: 0.462173  [  704/  750]
# train accuracy:		86.8%, train loss:		0.006890
# validation accuracy:	86.7%, validation loss:		0.007592
#
# Epoch 101
# -------------------------------
# loss: 0.675262  [   64/  750]
# loss: 0.510485  [  704/  750]
# train accuracy:		80.4%, train loss:		0.008307
# validation accuracy:	86.7%, validation loss:		0.007746
#
# Epoch 102
# -------------------------------
# loss: 0.459294  [   64/  750]
# loss: 0.526506  [  704/  750]
# train accuracy:		82.1%, train loss:		0.007836
# validation accuracy:	87.3%, validation loss:		0.009554
#
# Epoch 103
# -------------------------------
# loss: 0.420407  [   64/  750]
# loss: 0.412452  [  704/  750]
# train accuracy:		82.4%, train loss:		0.007663
# validation accuracy:	85.3%, validation loss:		0.009250
#
# Epoch 104
# -------------------------------
# loss: 0.484566  [   64/  750]
# loss: 0.517928  [  704/  750]
# train accuracy:		83.7%, train loss:		0.007184
# validation accuracy:	87.3%, validation loss:		0.007953
#
# Epoch 105
# -------------------------------
# loss: 0.500522  [   64/  750]
# loss: 0.664017  [  704/  750]
# train accuracy:		80.1%, train loss:		0.008702
# validation accuracy:	86.7%, validation loss:		0.008622
#
# Epoch 106
# -------------------------------
# loss: 0.506762  [   64/  750]
# loss: 0.449581  [  704/  750]
# train accuracy:		85.2%, train loss:		0.006957
# validation accuracy:	92.7%, validation loss:		0.006493
#
# Epoch 107
# -------------------------------
# loss: 0.427980  [   64/  750]
# loss: 0.531617  [  704/  750]
# train accuracy:		84.8%, train loss:		0.007168
# validation accuracy:	85.3%, validation loss:		0.007286
#
# Epoch 108
# -------------------------------
# loss: 0.624307  [   64/  750]
# loss: 0.492321  [  704/  750]
# train accuracy:		82.5%, train loss:		0.007616
# validation accuracy:	86.7%, validation loss:		0.010054
#
# Epoch 109
# -------------------------------
# loss: 0.493025  [   64/  750]
# loss: 0.375726  [  704/  750]
# train accuracy:		86.3%, train loss:		0.006430
# validation accuracy:	86.7%, validation loss:		0.008051
#
# Epoch 110
# -------------------------------
# loss: 0.544415  [   64/  750]
# loss: 0.533185  [  704/  750]
# train accuracy:		85.2%, train loss:		0.006775
# validation accuracy:	75.3%, validation loss:		0.009917
#
# Epoch 111
# -------------------------------
# loss: 0.414536  [   64/  750]
# loss: 0.556968  [  704/  750]
# train accuracy:		83.7%, train loss:		0.007077
# validation accuracy:	88.0%, validation loss:		0.006766
#
# Epoch 112
# -------------------------------
# loss: 0.391576  [   64/  750]
# loss: 0.484763  [  704/  750]
# train accuracy:		86.8%, train loss:		0.006465
# validation accuracy:	82.7%, validation loss:		0.008069
#
# Epoch 113
# -------------------------------
# loss: 0.618212  [   64/  750]
# loss: 0.419336  [  704/  750]
# train accuracy:		88.3%, train loss:		0.006278
# validation accuracy:	91.3%, validation loss:		0.006649
#
# Epoch 114
# -------------------------------
# loss: 0.584902  [   64/  750]
# loss: 0.373765  [  704/  750]
# train accuracy:		84.4%, train loss:		0.006532
# validation accuracy:	88.0%, validation loss:		0.007613
#
# Epoch 115
# -------------------------------
# loss: 0.302680  [   64/  750]
# loss: 0.385592  [  704/  750]
# train accuracy:		84.4%, train loss:		0.007162
# validation accuracy:	76.7%, validation loss:		0.010294
#
# Epoch 116
# -------------------------------
# loss: 0.717441  [   64/  750]
# loss: 0.518454  [  704/  750]
# train accuracy:		85.9%, train loss:		0.007009
# validation accuracy:	80.0%, validation loss:		0.011445
#
# Epoch 117
# -------------------------------
# loss: 0.470737  [   64/  750]
# loss: 0.367656  [  704/  750]
# train accuracy:		85.5%, train loss:		0.006413
# validation accuracy:	90.7%, validation loss:		0.006134
#
# Epoch 118
# -------------------------------
# loss: 0.406826  [   64/  750]
# loss: 0.446624  [  704/  750]
# train accuracy:		87.3%, train loss:		0.006021
# validation accuracy:	84.0%, validation loss:		0.009925
#
# Epoch 119
# -------------------------------
# loss: 0.502580  [   64/  750]
# loss: 0.520233  [  704/  750]
# train accuracy:		85.9%, train loss:		0.006959
# validation accuracy:	88.0%, validation loss:		0.006733
#
# Epoch 120
# -------------------------------
# loss: 0.339671  [   64/  750]
# loss: 0.400873  [  704/  750]
# train accuracy:		83.7%, train loss:		0.006836
# validation accuracy:	91.3%, validation loss:		0.006039
#
# Epoch 121
# -------------------------------
# loss: 0.303767  [   64/  750]
# loss: 0.598182  [  704/  750]
# train accuracy:		86.4%, train loss:		0.006499
# validation accuracy:	88.7%, validation loss:		0.006365
#
# Epoch 122
# -------------------------------
# loss: 0.242171  [   64/  750]
# loss: 0.301777  [  704/  750]
# train accuracy:		85.5%, train loss:		0.006478
# validation accuracy:	90.7%, validation loss:		0.006526
#
# Epoch 123
# -------------------------------
# loss: 0.403356  [   64/  750]
# loss: 0.399441  [  704/  750]
# train accuracy:		90.1%, train loss:		0.005326
# validation accuracy:	86.0%, validation loss:		0.007305
#
# Epoch 124
# -------------------------------
# loss: 0.307881  [   64/  750]
# loss: 0.280828  [  704/  750]
# train accuracy:		89.6%, train loss:		0.005501
# validation accuracy:	89.3%, validation loss:		0.006397
#
# Epoch 125
# -------------------------------
# loss: 0.339980  [   64/  750]
# loss: 0.390554  [  704/  750]
# train accuracy:		88.3%, train loss:		0.005745
# validation accuracy:	90.0%, validation loss:		0.006966
#
# Epoch 126
# -------------------------------
# loss: 0.315302  [   64/  750]
# loss: 0.286717  [  704/  750]
# train accuracy:		87.1%, train loss:		0.005860
# validation accuracy:	90.7%, validation loss:		0.005963
#
# Epoch 127
# -------------------------------
# loss: 0.325250  [   64/  750]
# loss: 0.343385  [  704/  750]
# train accuracy:		81.7%, train loss:		0.007631
# validation accuracy:	94.0%, validation loss:		0.005279
#
# Epoch 128
# -------------------------------
# loss: 0.332374  [   64/  750]
# loss: 0.406066  [  704/  750]
# train accuracy:		87.6%, train loss:		0.005779
# validation accuracy:	93.3%, validation loss:		0.005241
#
# Epoch 129
# -------------------------------
# loss: 0.301232  [   64/  750]
# loss: 0.343255  [  704/  750]
# train accuracy:		86.8%, train loss:		0.006130
# validation accuracy:	88.0%, validation loss:		0.008185
#
# Epoch 130
# -------------------------------
# loss: 0.447787  [   64/  750]
# loss: 0.276671  [  704/  750]
# train accuracy:		87.2%, train loss:		0.005609
# validation accuracy:	88.7%, validation loss:		0.006853
#
# Epoch 131
# -------------------------------
# loss: 0.671816  [   64/  750]
# loss: 0.393980  [  704/  750]
# train accuracy:		84.4%, train loss:		0.007385
# validation accuracy:	92.7%, validation loss:		0.006090
#
# Epoch 132
# -------------------------------
# loss: 0.388151  [   64/  750]
# loss: 0.407476  [  704/  750]
# train accuracy:		88.3%, train loss:		0.005634
# validation accuracy:	84.0%, validation loss:		0.008574
#
# Epoch 133
# -------------------------------
# loss: 0.256705  [   64/  750]
# loss: 0.361266  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005826
# validation accuracy:	91.3%, validation loss:		0.006024
#
# Epoch 134
# -------------------------------
# loss: 0.418759  [   64/  750]
# loss: 0.334476  [  704/  750]
# train accuracy:		86.1%, train loss:		0.006356
# validation accuracy:	88.7%, validation loss:		0.008345
#
# Epoch 135
# -------------------------------
# loss: 0.381916  [   64/  750]
# loss: 0.231707  [  704/  750]
# train accuracy:		89.3%, train loss:		0.005398
# validation accuracy:	88.0%, validation loss:		0.006706
#
# Epoch 136
# -------------------------------
# loss: 0.252328  [   64/  750]
# loss: 0.365718  [  704/  750]
# train accuracy:		88.4%, train loss:		0.005309
# validation accuracy:	85.3%, validation loss:		0.009020
#
# Epoch 137
# -------------------------------
# loss: 0.309490  [   64/  750]
# loss: 0.366729  [  704/  750]
# train accuracy:		86.9%, train loss:		0.005749
# validation accuracy:	88.7%, validation loss:		0.005646
#
# Epoch 138
# -------------------------------
# loss: 0.267802  [   64/  750]
# loss: 0.237773  [  704/  750]
# train accuracy:		90.1%, train loss:		0.005198
# validation accuracy:	91.3%, validation loss:		0.005916
#
# Epoch 139
# -------------------------------
# loss: 0.389122  [   64/  750]
# loss: 0.447689  [  704/  750]
# train accuracy:		84.9%, train loss:		0.006375
# validation accuracy:	87.3%, validation loss:		0.006834
#
# Epoch 140
# -------------------------------
# loss: 0.277374  [   64/  750]
# loss: 0.375835  [  704/  750]
# train accuracy:		84.8%, train loss:		0.006451
# validation accuracy:	88.0%, validation loss:		0.005622
#
# Epoch 141
# -------------------------------
# loss: 0.367988  [   64/  750]
# loss: 0.276856  [  704/  750]
# train accuracy:		86.8%, train loss:		0.006007
# validation accuracy:	79.3%, validation loss:		0.007646
#
# Epoch 142
# -------------------------------
# loss: 0.292260  [   64/  750]
# loss: 0.343579  [  704/  750]
# train accuracy:		87.3%, train loss:		0.005667
# validation accuracy:	90.7%, validation loss:		0.006168
#
# Epoch 143
# -------------------------------
# loss: 0.364251  [   64/  750]
# loss: 0.290169  [  704/  750]
# train accuracy:		88.0%, train loss:		0.005348
# validation accuracy:	90.7%, validation loss:		0.005635
#
# Epoch 144
# -------------------------------
# loss: 0.295941  [   64/  750]
# loss: 0.440580  [  704/  750]
# train accuracy:		84.3%, train loss:		0.006256
# validation accuracy:	90.0%, validation loss:		0.005722
#
# Epoch 145
# -------------------------------
# loss: 0.425689  [   64/  750]
# loss: 0.352991  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005690
# validation accuracy:	86.7%, validation loss:		0.007789
#
# Epoch 146
# -------------------------------
# loss: 0.510935  [   64/  750]
# loss: 0.419817  [  704/  750]
# train accuracy:		86.9%, train loss:		0.005458
# validation accuracy:	89.3%, validation loss:		0.006206
#
# Epoch 147
# -------------------------------
# loss: 0.352908  [   64/  750]
# loss: 0.267395  [  704/  750]
# train accuracy:		87.5%, train loss:		0.005595
# validation accuracy:	84.0%, validation loss:		0.010038
#
# Epoch 148
# -------------------------------
# loss: 0.609754  [   64/  750]
# loss: 0.276600  [  704/  750]
# train accuracy:		85.7%, train loss:		0.006123
# validation accuracy:	93.3%, validation loss:		0.004927
#
# Epoch 149
# -------------------------------
# loss: 0.240605  [   64/  750]
# loss: 0.290143  [  704/  750]
# train accuracy:		86.8%, train loss:		0.005637
# validation accuracy:	84.7%, validation loss:		0.006303
#
# Epoch 150
# -------------------------------
# loss: 0.310256  [   64/  750]
# loss: 0.397533  [  704/  750]
# train accuracy:		87.3%, train loss:		0.005318
# validation accuracy:	92.7%, validation loss:		0.005556
#
# Epoch 151
# -------------------------------
# loss: 0.465516  [   64/  750]
# loss: 0.282085  [  704/  750]
# train accuracy:		86.1%, train loss:		0.005799
# validation accuracy:	92.7%, validation loss:		0.005941
#
# Epoch 152
# -------------------------------
# loss: 0.394461  [   64/  750]
# loss: 0.430651  [  704/  750]
# train accuracy:		86.8%, train loss:		0.005828
# validation accuracy:	91.3%, validation loss:		0.005596
#
# Epoch 153
# -------------------------------
# loss: 0.353137  [   64/  750]
# loss: 0.222989  [  704/  750]
# train accuracy:		89.6%, train loss:		0.004843
# validation accuracy:	90.7%, validation loss:		0.005221
#
# Epoch 154
# -------------------------------
# loss: 0.264436  [   64/  750]
# loss: 0.327568  [  704/  750]
# train accuracy:		87.5%, train loss:		0.005468
# validation accuracy:	88.0%, validation loss:		0.006746
#
# Epoch 155
# -------------------------------
# loss: 0.329860  [   64/  750]
# loss: 0.281381  [  704/  750]
# train accuracy:		87.7%, train loss:		0.005281
# validation accuracy:	94.0%, validation loss:		0.004067
#
# Epoch 156
# -------------------------------
# loss: 0.243048  [   64/  750]
# loss: 0.304773  [  704/  750]
# train accuracy:		88.3%, train loss:		0.005627
# validation accuracy:	89.3%, validation loss:		0.005698
#
# Epoch 157
# -------------------------------
# loss: 0.196597  [   64/  750]
# loss: 0.289822  [  704/  750]
# train accuracy:		89.2%, train loss:		0.004741
# validation accuracy:	94.7%, validation loss:		0.004477
#
# Epoch 158
# -------------------------------
# loss: 0.337405  [   64/  750]
# loss: 0.152676  [  704/  750]
# train accuracy:		88.8%, train loss:		0.004705
# validation accuracy:	92.7%, validation loss:		0.004337
#
# Epoch 159
# -------------------------------
# loss: 0.301039  [   64/  750]
# loss: 0.345352  [  704/  750]
# train accuracy:		87.7%, train loss:		0.005490
# validation accuracy:	94.7%, validation loss:		0.005168
#
# Epoch 160
# -------------------------------
# loss: 0.372848  [   64/  750]
# loss: 0.356994  [  704/  750]
# train accuracy:		88.8%, train loss:		0.004966
# validation accuracy:	88.0%, validation loss:		0.006474
#
# Epoch 161
# -------------------------------
# loss: 0.256460  [   64/  750]
# loss: 0.353229  [  704/  750]
# train accuracy:		82.4%, train loss:		0.006492
# validation accuracy:	89.3%, validation loss:		0.005375
#
# Epoch 162
# -------------------------------
# loss: 0.301075  [   64/  750]
# loss: 0.416309  [  704/  750]
# train accuracy:		89.1%, train loss:		0.004865
# validation accuracy:	94.7%, validation loss:		0.003988
#
# Epoch 163
# -------------------------------
# loss: 0.354941  [   64/  750]
# loss: 0.250980  [  704/  750]
# train accuracy:		87.2%, train loss:		0.005903
# validation accuracy:	90.0%, validation loss:		0.005339
#
# Epoch 164
# -------------------------------
# loss: 0.302171  [   64/  750]
# loss: 0.241750  [  704/  750]
# train accuracy:		90.4%, train loss:		0.004586
# validation accuracy:	94.0%, validation loss:		0.005049
#
# Epoch 165
# -------------------------------
# loss: 0.264381  [   64/  750]
# loss: 0.426231  [  704/  750]
# train accuracy:		88.4%, train loss:		0.005216
# validation accuracy:	91.3%, validation loss:		0.005171
#
# Epoch 166
# -------------------------------
# loss: 0.684034  [   64/  750]
# loss: 0.275858  [  704/  750]
# train accuracy:		86.8%, train loss:		0.005778
# validation accuracy:	88.7%, validation loss:		0.006507
#
# Epoch 167
# -------------------------------
# loss: 0.316413  [   64/  750]
# loss: 0.283046  [  704/  750]
# train accuracy:		88.3%, train loss:		0.005908
# validation accuracy:	92.7%, validation loss:		0.004843
#
# Epoch 168
# -------------------------------
# loss: 0.239362  [   64/  750]
# loss: 0.356684  [  704/  750]
# train accuracy:		90.4%, train loss:		0.004652
# validation accuracy:	80.7%, validation loss:		0.007171
#
# Epoch 169
# -------------------------------
# loss: 0.226469  [   64/  750]
# loss: 0.460871  [  704/  750]
# train accuracy:		87.7%, train loss:		0.005220
# validation accuracy:	92.0%, validation loss:		0.004568
#
# Epoch 170
# -------------------------------
# loss: 0.493512  [   64/  750]
# loss: 0.327016  [  704/  750]
# train accuracy:		84.0%, train loss:		0.006223
# validation accuracy:	93.3%, validation loss:		0.004257
#
# Epoch 171
# -------------------------------
# loss: 0.282446  [   64/  750]
# loss: 0.246429  [  704/  750]
# train accuracy:		90.3%, train loss:		0.004438
# validation accuracy:	86.0%, validation loss:		0.006708
#
# Epoch 172
# -------------------------------
# loss: 0.484510  [   64/  750]
# loss: 0.358495  [  704/  750]
# train accuracy:		88.0%, train loss:		0.005070
# validation accuracy:	94.7%, validation loss:		0.005133
#
# Epoch 173
# -------------------------------
# loss: 0.302756  [   64/  750]
# loss: 0.374881  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005735
# validation accuracy:	90.7%, validation loss:		0.004869
#
# Epoch 174
# -------------------------------
# loss: 0.374518  [   64/  750]
# loss: 0.400276  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005637
# validation accuracy:	92.7%, validation loss:		0.004388
#
# Epoch 175
# -------------------------------
# loss: 0.180724  [   64/  750]
# loss: 0.209304  [  704/  750]
# train accuracy:		88.9%, train loss:		0.004747
# validation accuracy:	92.7%, validation loss:		0.004546
#
# Epoch 176
# -------------------------------
# loss: 0.234869  [   64/  750]
# loss: 0.212931  [  704/  750]
# train accuracy:		90.3%, train loss:		0.004401
# validation accuracy:	91.3%, validation loss:		0.004923
#
# Epoch 177
# -------------------------------
# loss: 0.179606  [   64/  750]
# loss: 0.319761  [  704/  750]
# train accuracy:		87.2%, train loss:		0.005333
# validation accuracy:	93.3%, validation loss:		0.004264
#
# Epoch 178
# -------------------------------
# loss: 0.207609  [   64/  750]
# loss: 0.239532  [  704/  750]
# train accuracy:		87.3%, train loss:		0.005033
# validation accuracy:	95.3%, validation loss:		0.003503
#
# Epoch 179
# -------------------------------
# loss: 0.312213  [   64/  750]
# loss: 0.385266  [  704/  750]
# train accuracy:		87.5%, train loss:		0.005154
# validation accuracy:	94.0%, validation loss:		0.004670
#
# Epoch 180
# -------------------------------
# loss: 0.931107  [   64/  750]
# loss: 0.249639  [  704/  750]
# train accuracy:		89.1%, train loss:		0.005276
# validation accuracy:	93.3%, validation loss:		0.003890
#
# Epoch 181
# -------------------------------
# loss: 0.339616  [   64/  750]
# loss: 0.217967  [  704/  750]
# train accuracy:		87.1%, train loss:		0.005210
# validation accuracy:	91.3%, validation loss:		0.005109
#
# Epoch 182
# -------------------------------
# loss: 0.237187  [   64/  750]
# loss: 0.333576  [  704/  750]
# train accuracy:		88.1%, train loss:		0.005007
# validation accuracy:	94.7%, validation loss:		0.003514
#
# Epoch 183
# -------------------------------
# loss: 0.377934  [   64/  750]
# loss: 0.256988  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005202
# validation accuracy:	93.3%, validation loss:		0.004464
#
# Epoch 184
# -------------------------------
# loss: 0.325280  [   64/  750]
# loss: 0.509020  [  704/  750]
# train accuracy:		88.0%, train loss:		0.005546
# validation accuracy:	94.7%, validation loss:		0.004065
#
# Epoch 185
# -------------------------------
# loss: 0.379616  [   64/  750]
# loss: 0.241219  [  704/  750]
# train accuracy:		89.1%, train loss:		0.004879
# validation accuracy:	94.0%, validation loss:		0.004452
#
# Epoch 186
# -------------------------------
# loss: 0.279065  [   64/  750]
# loss: 0.198296  [  704/  750]
# train accuracy:		86.4%, train loss:		0.005767
# validation accuracy:	94.7%, validation loss:		0.003741
#
# Epoch 187
# -------------------------------
# loss: 0.250130  [   64/  750]
# loss: 0.291338  [  704/  750]
# train accuracy:		90.5%, train loss:		0.004518
# validation accuracy:	92.7%, validation loss:		0.005301
#
# Epoch 188
# -------------------------------
# loss: 0.290865  [   64/  750]
# loss: 0.397235  [  704/  750]
# train accuracy:		85.1%, train loss:		0.005754
# validation accuracy:	92.0%, validation loss:		0.004325
#
# Epoch 189
# -------------------------------
# loss: 0.214001  [   64/  750]
# loss: 0.330553  [  704/  750]
# train accuracy:		90.9%, train loss:		0.004478
# validation accuracy:	93.3%, validation loss:		0.003845
#
# Epoch 190
# -------------------------------
# loss: 0.220721  [   64/  750]
# loss: 0.398452  [  704/  750]
# train accuracy:		89.1%, train loss:		0.005217
# validation accuracy:	92.0%, validation loss:		0.004562
#
# Epoch 191
# -------------------------------
# loss: 0.734099  [   64/  750]
# loss: 0.285354  [  704/  750]
# train accuracy:		86.9%, train loss:		0.005757
# validation accuracy:	92.0%, validation loss:		0.004093
#
# Epoch 192
# -------------------------------
# loss: 0.249835  [   64/  750]
# loss: 0.385166  [  704/  750]
# train accuracy:		89.3%, train loss:		0.004709
# validation accuracy:	93.3%, validation loss:		0.003958
#
# Epoch 193
# -------------------------------
# loss: 0.301648  [   64/  750]
# loss: 0.295641  [  704/  750]
# train accuracy:		88.0%, train loss:		0.005419
# validation accuracy:	95.3%, validation loss:		0.003112
#
# Epoch 194
# -------------------------------
# loss: 0.200719  [   64/  750]
# loss: 0.151668  [  704/  750]
# train accuracy:		91.1%, train loss:		0.004163
# validation accuracy:	94.0%, validation loss:		0.003879
#
# Epoch 195
# -------------------------------
# loss: 0.325694  [   64/  750]
# loss: 0.241702  [  704/  750]
# train accuracy:		87.6%, train loss:		0.004694
# validation accuracy:	89.3%, validation loss:		0.004497
#
# Epoch 196
# -------------------------------
# loss: 0.231316  [   64/  750]
# loss: 0.235620  [  704/  750]
# train accuracy:		89.9%, train loss:		0.004701
# validation accuracy:	94.7%, validation loss:		0.003192
#
# Epoch 197
# -------------------------------
# loss: 0.394697  [   64/  750]
# loss: 0.492631  [  704/  750]
# train accuracy:		89.1%, train loss:		0.005033
# validation accuracy:	96.0%, validation loss:		0.002533
#
# Epoch 198
# -------------------------------
# loss: 0.369517  [   64/  750]
# loss: 0.170238  [  704/  750]
# train accuracy:		91.5%, train loss:		0.004271
# validation accuracy:	94.0%, validation loss:		0.003741
#
# Epoch 199
# -------------------------------
# loss: 0.232136  [   64/  750]
# loss: 0.352087  [  704/  750]
# train accuracy:		90.7%, train loss:		0.003927
# validation accuracy:	94.0%, validation loss:		0.003578
#
# Epoch 200
# -------------------------------
# loss: 0.288566  [   64/  750]
# loss: 0.208079  [  704/  750]
# train accuracy:		87.6%, train loss:		0.005357
# validation accuracy:	94.0%, validation loss:		0.003971
#
# Epoch 201
# -------------------------------
# loss: 0.247660  [   64/  750]
# loss: 0.203373  [  704/  750]
# train accuracy:		91.6%, train loss:		0.004227
# validation accuracy:	96.0%, validation loss:		0.002613
#
# Epoch 202
# -------------------------------
# loss: 0.201604  [   64/  750]
# loss: 0.193232  [  704/  750]
# train accuracy:		89.6%, train loss:		0.004686
# validation accuracy:	95.3%, validation loss:		0.003003
#
# Epoch 203
# -------------------------------
# loss: 0.253192  [   64/  750]
# loss: 0.330672  [  704/  750]
# train accuracy:		90.4%, train loss:		0.004463
# validation accuracy:	93.3%, validation loss:		0.004072
#
# Epoch 204
# -------------------------------
# loss: 0.222297  [   64/  750]
# loss: 0.214655  [  704/  750]
# train accuracy:		91.5%, train loss:		0.003748
# validation accuracy:	85.3%, validation loss:		0.004757
#
# Epoch 205
# -------------------------------
# loss: 0.341613  [   64/  750]
# loss: 0.178304  [  704/  750]
# train accuracy:		91.1%, train loss:		0.004536
# validation accuracy:	94.0%, validation loss:		0.003611
#
# Epoch 206
# -------------------------------
# loss: 0.223996  [   64/  750]
# loss: 0.303198  [  704/  750]
# train accuracy:		92.7%, train loss:		0.003863
# validation accuracy:	94.0%, validation loss:		0.003221
#
# Epoch 207
# -------------------------------
# loss: 0.397489  [   64/  750]
# loss: 0.224266  [  704/  750]
# train accuracy:		87.6%, train loss:		0.004879
# validation accuracy:	91.3%, validation loss:		0.003983
#
# Epoch 208
# -------------------------------
# loss: 0.246115  [   64/  750]
# loss: 0.599366  [  704/  750]
# train accuracy:		84.0%, train loss:		0.007968
# validation accuracy:	90.7%, validation loss:		0.005850
#
# Epoch 209
# -------------------------------
# loss: 0.482958  [   64/  750]
# loss: 0.341660  [  704/  750]
# train accuracy:		88.5%, train loss:		0.004621
# validation accuracy:	96.7%, validation loss:		0.002840
#
# Epoch 210
# -------------------------------
# loss: 0.205478  [   64/  750]
# loss: 0.268886  [  704/  750]
# train accuracy:		91.2%, train loss:		0.003838
# validation accuracy:	94.7%, validation loss:		0.003027
#
# Epoch 211
# -------------------------------
# loss: 0.270845  [   64/  750]
# loss: 0.313858  [  704/  750]
# train accuracy:		91.1%, train loss:		0.004011
# validation accuracy:	92.7%, validation loss:		0.004059
#
# Epoch 212
# -------------------------------
# loss: 0.532631  [   64/  750]
# loss: 0.286777  [  704/  750]
# train accuracy:		89.6%, train loss:		0.004649
# validation accuracy:	98.0%, validation loss:		0.002589
#
# Epoch 213
# -------------------------------
# loss: 0.306654  [   64/  750]
# loss: 0.188874  [  704/  750]
# train accuracy:		91.3%, train loss:		0.003861
# validation accuracy:	94.0%, validation loss:		0.003504
#
# Epoch 214
# -------------------------------
# loss: 0.304715  [   64/  750]
# loss: 0.288295  [  704/  750]
# train accuracy:		89.9%, train loss:		0.004225
# validation accuracy:	96.7%, validation loss:		0.002531
#
# Epoch 215
# -------------------------------
# loss: 0.235879  [   64/  750]
# loss: 0.173570  [  704/  750]
# train accuracy:		89.5%, train loss:		0.004627
# validation accuracy:	95.3%, validation loss:		0.003731
#
# Epoch 216
# -------------------------------
# loss: 0.223409  [   64/  750]
# loss: 0.388740  [  704/  750]
# train accuracy:		91.7%, train loss:		0.003912
# validation accuracy:	90.7%, validation loss:		0.005165
#
# Epoch 217
# -------------------------------
# loss: 0.639273  [   64/  750]
# loss: 0.346903  [  704/  750]
# train accuracy:		91.6%, train loss:		0.004293
# validation accuracy:	94.7%, validation loss:		0.003258
#
# Epoch 218
# -------------------------------
# loss: 0.319784  [   64/  750]
# loss: 0.358987  [  704/  750]
# train accuracy:		91.2%, train loss:		0.003979
# validation accuracy:	97.3%, validation loss:		0.002966
#
# Epoch 219
# -------------------------------
# loss: 0.414140  [   64/  750]
# loss: 0.295149  [  704/  750]
# train accuracy:		91.9%, train loss:		0.003985
# validation accuracy:	96.0%, validation loss:		0.002540
#
# Epoch 220
# -------------------------------
# loss: 0.245166  [   64/  750]
# loss: 0.165529  [  704/  750]
# train accuracy:		91.2%, train loss:		0.004018
# validation accuracy:	98.0%, validation loss:		0.002679
#
# Epoch 221
# -------------------------------
# loss: 0.363736  [   64/  750]
# loss: 0.245106  [  704/  750]
# train accuracy:		88.9%, train loss:		0.004623
# validation accuracy:	97.3%, validation loss:		0.002165
#
# Epoch 222
# -------------------------------
# loss: 0.263145  [   64/  750]
# loss: 0.374671  [  704/  750]
# train accuracy:		87.7%, train loss:		0.004997
# validation accuracy:	95.3%, validation loss:		0.003206
#
# Epoch 223
# -------------------------------
# loss: 0.197208  [   64/  750]
# loss: 0.214198  [  704/  750]
# train accuracy:		92.0%, train loss:		0.003534
# validation accuracy:	92.7%, validation loss:		0.003317
#
# Epoch 224
# -------------------------------
# loss: 0.390123  [   64/  750]
# loss: 0.195674  [  704/  750]
# train accuracy:		90.5%, train loss:		0.004129
# validation accuracy:	92.7%, validation loss:		0.003487
#
# Epoch 225
# -------------------------------
# loss: 0.263432  [   64/  750]
# loss: 0.217355  [  704/  750]
# train accuracy:		90.7%, train loss:		0.004149
# validation accuracy:	94.7%, validation loss:		0.003211
#
# Epoch 226
# -------------------------------
# loss: 0.328042  [   64/  750]
# loss: 0.259210  [  704/  750]
# train accuracy:		88.1%, train loss:		0.004857
# validation accuracy:	99.3%, validation loss:		0.002417
#
# Epoch 227
# -------------------------------
# loss: 0.159277  [   64/  750]
# loss: 0.181313  [  704/  750]
# train accuracy:		91.6%, train loss:		0.003802
# validation accuracy:	98.0%, validation loss:		0.002128
#
# Epoch 228
# -------------------------------
# loss: 0.278373  [   64/  750]
# loss: 0.197693  [  704/  750]
# train accuracy:		92.3%, train loss:		0.003764
# validation accuracy:	96.7%, validation loss:		0.002406
#
# Epoch 229
# -------------------------------
# loss: 0.193830  [   64/  750]
# loss: 0.254024  [  704/  750]
# train accuracy:		92.1%, train loss:		0.003782
# validation accuracy:	96.7%, validation loss:		0.002407
#
# Epoch 230
# -------------------------------
# loss: 0.230756  [   64/  750]
# loss: 0.220781  [  704/  750]
# train accuracy:		91.1%, train loss:		0.004106
# validation accuracy:	98.0%, validation loss:		0.001883
#
# Epoch 231
# -------------------------------
# loss: 0.207980  [   64/  750]
# loss: 0.400434  [  704/  750]
# train accuracy:		91.5%, train loss:		0.003916
# validation accuracy:	98.7%, validation loss:		0.002016
#
# Epoch 232
# -------------------------------
# loss: 0.326662  [   64/  750]
# loss: 0.315682  [  704/  750]
# train accuracy:		90.7%, train loss:		0.004038
# validation accuracy:	83.3%, validation loss:		0.005323
#
# Epoch 233
# -------------------------------
# loss: 0.506142  [   64/  750]
# loss: 0.153619  [  704/  750]
# train accuracy:		89.5%, train loss:		0.004173
# validation accuracy:	97.3%, validation loss:		0.002378
#
# Epoch 234
# -------------------------------
# loss: 0.202086  [   64/  750]
# loss: 0.266601  [  704/  750]
# train accuracy:		93.2%, train loss:		0.003497
# validation accuracy:	97.3%, validation loss:		0.002027
#
# Epoch 235
# -------------------------------
# loss: 0.289220  [   64/  750]
# loss: 0.187836  [  704/  750]
# train accuracy:		92.0%, train loss:		0.003546
# validation accuracy:	96.0%, validation loss:		0.002596
#
# Epoch 236
# -------------------------------
# loss: 0.181502  [   64/  750]
# loss: 0.284479  [  704/  750]
# train accuracy:		90.4%, train loss:		0.003944
# validation accuracy:	97.3%, validation loss:		0.002214
#
# Epoch 237
# -------------------------------
# loss: 0.178830  [   64/  750]
# loss: 0.594723  [  704/  750]
# train accuracy:		90.5%, train loss:		0.004356
# validation accuracy:	96.7%, validation loss:		0.002100
#
# Epoch 238
# -------------------------------
# loss: 0.261498  [   64/  750]
# loss: 0.136677  [  704/  750]
# train accuracy:		92.7%, train loss:		0.003596
# validation accuracy:	92.7%, validation loss:		0.003270
#
# Epoch 239
# -------------------------------
# loss: 0.210615  [   64/  750]
# loss: 0.218469  [  704/  750]
# train accuracy:		92.4%, train loss:		0.003571
# validation accuracy:	90.7%, validation loss:		0.004510
#
# Epoch 240
# -------------------------------
# loss: 0.577641  [   64/  750]
# loss: 0.224537  [  704/  750]
# train accuracy:		91.6%, train loss:		0.004124
# validation accuracy:	94.0%, validation loss:		0.002972
#
# Epoch 241
# -------------------------------
# loss: 0.366901  [   64/  750]
# loss: 0.205059  [  704/  750]
# train accuracy:		89.7%, train loss:		0.004368
# validation accuracy:	97.3%, validation loss:		0.002022
#
# Epoch 242
# -------------------------------
# loss: 0.293016  [   64/  750]
# loss: 0.136573  [  704/  750]
# train accuracy:		91.7%, train loss:		0.003364
# validation accuracy:	96.7%, validation loss:		0.002241
#
# Epoch 243
# -------------------------------
# loss: 0.196059  [   64/  750]
# loss: 0.171321  [  704/  750]
# train accuracy:		93.6%, train loss:		0.003191
# validation accuracy:	96.7%, validation loss:		0.002305
#
# Epoch 244
# -------------------------------
# loss: 0.223787  [   64/  750]
# loss: 0.157219  [  704/  750]
# train accuracy:		91.1%, train loss:		0.004081
# validation accuracy:	99.3%, validation loss:		0.001558
#
# Epoch 245
# -------------------------------
# loss: 0.239140  [   64/  750]
# loss: 0.481035  [  704/  750]
# train accuracy:		90.8%, train loss:		0.004181
# validation accuracy:	98.7%, validation loss:		0.002023
#
# Epoch 246
# -------------------------------
# loss: 0.211144  [   64/  750]
# loss: 0.280185  [  704/  750]
# train accuracy:		90.3%, train loss:		0.005040
# validation accuracy:	82.0%, validation loss:		0.008045
#
# Epoch 247
# -------------------------------
# loss: 0.627833  [   64/  750]
# loss: 0.216063  [  704/  750]
# train accuracy:		90.5%, train loss:		0.004237
# validation accuracy:	98.0%, validation loss:		0.001692
#
# Epoch 248
# -------------------------------
# loss: 0.189884  [   64/  750]
# loss: 0.221294  [  704/  750]
# train accuracy:		92.9%, train loss:		0.003472
# validation accuracy:	97.3%, validation loss:		0.002030
#
# Epoch 249
# -------------------------------
# loss: 0.170763  [   64/  750]
# loss: 0.126188  [  704/  750]
# train accuracy:		91.3%, train loss:		0.003814
# validation accuracy:	96.0%, validation loss:		0.002454
#
# Epoch 250
# -------------------------------
# loss: 0.288009  [   64/  750]
# loss: 0.149153  [  704/  750]
# train accuracy:		93.2%, train loss:		0.003307
# validation accuracy:	98.0%, validation loss:		0.002060
#
# Epoch 251
# -------------------------------
# loss: 0.134519  [   64/  750]
# loss: 0.514685  [  704/  750]
# train accuracy:		88.9%, train loss:		0.004278
# validation accuracy:	94.0%, validation loss:		0.003287
#
# Epoch 252
# -------------------------------
# loss: 0.415459  [   64/  750]
# loss: 0.217774  [  704/  750]
# train accuracy:		92.4%, train loss:		0.003766
# validation accuracy:	97.3%, validation loss:		0.001875
#
# Epoch 253
# -------------------------------
# loss: 0.246599  [   64/  750]
# loss: 0.171326  [  704/  750]
# train accuracy:		93.2%, train loss:		0.003415
# validation accuracy:	98.0%, validation loss:		0.002278
#
# Epoch 254
# -------------------------------
# loss: 0.161131  [   64/  750]
# loss: 0.207264  [  704/  750]
# train accuracy:		92.1%, train loss:		0.003616
# validation accuracy:	93.3%, validation loss:		0.003712
#
# Epoch 255
# -------------------------------
# loss: 0.379813  [   64/  750]
# loss: 0.218155  [  704/  750]
# train accuracy:		91.2%, train loss:		0.003862
# validation accuracy:	97.3%, validation loss:		0.002035
#
# Epoch 256
# -------------------------------
# loss: 0.157003  [   64/  750]
# loss: 0.289785  [  704/  750]
# train accuracy:		94.0%, train loss:		0.003136
# validation accuracy:	97.3%, validation loss:		0.001790
#
# Epoch 257
# -------------------------------
# loss: 0.167703  [   64/  750]
# loss: 0.212039  [  704/  750]
# train accuracy:		93.1%, train loss:		0.003210
# validation accuracy:	99.3%, validation loss:		0.001679
#
# Epoch 258
# -------------------------------
# loss: 0.171181  [   64/  750]
# loss: 0.163082  [  704/  750]
# train accuracy:		91.5%, train loss:		0.003617
# validation accuracy:	97.3%, validation loss:		0.001508
#
# Epoch 259
# -------------------------------
# loss: 0.184300  [   64/  750]
# loss: 0.276762  [  704/  750]
# train accuracy:		91.6%, train loss:		0.004048
# validation accuracy:	98.0%, validation loss:		0.001521
#
# Epoch 260
# -------------------------------
# loss: 0.233355  [   64/  750]
# loss: 0.226021  [  704/  750]
# train accuracy:		91.9%, train loss:		0.003981
# validation accuracy:	97.3%, validation loss:		0.001983
#
# Epoch 261
# -------------------------------
# loss: 0.199723  [   64/  750]
# loss: 0.148229  [  704/  750]
# train accuracy:		92.9%, train loss:		0.003167
# validation accuracy:	93.3%, validation loss:		0.002785
#
# Epoch 262
# -------------------------------
# loss: 0.219007  [   64/  750]
# loss: 0.317437  [  704/  750]
# train accuracy:		93.5%, train loss:		0.003342
# validation accuracy:	96.0%, validation loss:		0.002968
#
# Epoch 263
# -------------------------------
# loss: 0.367553  [   64/  750]
# loss: 0.146811  [  704/  750]
# train accuracy:		92.4%, train loss:		0.003911
# validation accuracy:	97.3%, validation loss:		0.001738
#
# Epoch 264
# -------------------------------
# loss: 0.127082  [   64/  750]
# loss: 0.277956  [  704/  750]
# train accuracy:		92.7%, train loss:		0.003031
# validation accuracy:	97.3%, validation loss:		0.001802
#
# Epoch 265
# -------------------------------
# loss: 0.145787  [   64/  750]
# loss: 0.236080  [  704/  750]
# train accuracy:		88.4%, train loss:		0.004438
# validation accuracy:	98.7%, validation loss:		0.002256
#
# Epoch 266
# -------------------------------
# loss: 0.292556  [   64/  750]
# loss: 0.173810  [  704/  750]
# train accuracy:		91.7%, train loss:		0.003591
# validation accuracy:	99.3%, validation loss:		0.001838
#
# Epoch 267
# -------------------------------
# loss: 0.240309  [   64/  750]
# loss: 0.187507  [  704/  750]
# train accuracy:		91.9%, train loss:		0.004096
# validation accuracy:	97.3%, validation loss:		0.001731
#
# Epoch 268
# -------------------------------
# loss: 0.192445  [   64/  750]
# loss: 0.317435  [  704/  750]
# train accuracy:		91.7%, train loss:		0.003755
# validation accuracy:	97.3%, validation loss:		0.001821
#
# Epoch 269
# -------------------------------
# loss: 0.176561  [   64/  750]
# loss: 0.226346  [  704/  750]
# train accuracy:		89.9%, train loss:		0.005378
# validation accuracy:	94.7%, validation loss:		0.004737
#
# Epoch 270
# -------------------------------
# loss: 0.273502  [   64/  750]
# loss: 0.299018  [  704/  750]
# train accuracy:		91.3%, train loss:		0.003829
# validation accuracy:	95.3%, validation loss:		0.002871
#
# Epoch 271
# -------------------------------
# loss: 0.206235  [   64/  750]
# loss: 0.130313  [  704/  750]
# train accuracy:		93.3%, train loss:		0.003259
# validation accuracy:	98.7%, validation loss:		0.001761
#
# Epoch 272
# -------------------------------
# loss: 0.234813  [   64/  750]
# loss: 0.120413  [  704/  750]
# train accuracy:		93.1%, train loss:		0.003176
# validation accuracy:	96.7%, validation loss:		0.002517
#
# Epoch 273
# -------------------------------
# loss: 0.307749  [   64/  750]
# loss: 0.153373  [  704/  750]
# train accuracy:		91.6%, train loss:		0.003744
# validation accuracy:	99.3%, validation loss:		0.001844
#
# Epoch 274
# -------------------------------
# loss: 0.150790  [   64/  750]
# loss: 0.157425  [  704/  750]
# train accuracy:		94.3%, train loss:		0.002854
# validation accuracy:	97.3%, validation loss:		0.001583
#
# Epoch 275
# -------------------------------
# loss: 0.208259  [   64/  750]
# loss: 0.270606  [  704/  750]
# train accuracy:		92.5%, train loss:		0.003253
# validation accuracy:	99.3%, validation loss:		0.001865
#
# Epoch 276
# -------------------------------
# loss: 0.210174  [   64/  750]
# loss: 0.214110  [  704/  750]
# train accuracy:		91.3%, train loss:		0.004235
# validation accuracy:	99.3%, validation loss:		0.001582
#
# Epoch 277
# -------------------------------
# loss: 0.288646  [   64/  750]
# loss: 0.205322  [  704/  750]
# train accuracy:		92.1%, train loss:		0.003405
# validation accuracy:	98.7%, validation loss:		0.001251
#
# Epoch 278
# -------------------------------
# loss: 0.130146  [   64/  750]
# loss: 0.170152  [  704/  750]
# train accuracy:		93.6%, train loss:		0.002727
# validation accuracy:	100.0%, validation loss:		0.001270
#
# Epoch 279
# -------------------------------
# loss: 0.198303  [   64/  750]
# loss: 0.173318  [  704/  750]
# train accuracy:		92.9%, train loss:		0.003007
# validation accuracy:	100.0%, validation loss:		0.001550
#
# Epoch 280
# -------------------------------
# loss: 0.227505  [   64/  750]
# loss: 0.235291  [  704/  750]
# train accuracy:		92.9%, train loss:		0.003780
# validation accuracy:	97.3%, validation loss:		0.001843
#
# Epoch 281
# -------------------------------
# loss: 0.081451  [   64/  750]
# loss: 0.343754  [  704/  750]
# train accuracy:		90.8%, train loss:		0.004245
# validation accuracy:	98.7%, validation loss:		0.002234
#
# Epoch 282
# -------------------------------
# loss: 0.278648  [   64/  750]
# loss: 0.131735  [  704/  750]
# train accuracy:		92.5%, train loss:		0.003082
# validation accuracy:	99.3%, validation loss:		0.001267
#
# Epoch 283
# -------------------------------
# loss: 0.135281  [   64/  750]
# loss: 0.198736  [  704/  750]
# train accuracy:		89.7%, train loss:		0.004679
# validation accuracy:	97.3%, validation loss:		0.001825
#
# Epoch 284
# -------------------------------
# loss: 0.315709  [   64/  750]
# loss: 0.392656  [  704/  750]
# train accuracy:		92.1%, train loss:		0.003686
# validation accuracy:	98.7%, validation loss:		0.001502
#
# Epoch 285
# -------------------------------
# loss: 0.204909  [   64/  750]
# loss: 0.178682  [  704/  750]
# train accuracy:		95.1%, train loss:		0.002891
# validation accuracy:	97.3%, validation loss:		0.001521
#
# Epoch 286
# -------------------------------
# loss: 0.222014  [   64/  750]
# loss: 0.413639  [  704/  750]
# train accuracy:		86.7%, train loss:		0.005341
# validation accuracy:	98.0%, validation loss:		0.001873
#
# Epoch 287
# -------------------------------
# loss: 0.124480  [   64/  750]
# loss: 0.224987  [  704/  750]
# train accuracy:		94.3%, train loss:		0.002977
# validation accuracy:	95.3%, validation loss:		0.002004
#
# Epoch 288
# -------------------------------
# loss: 0.100654  [   64/  750]
# loss: 0.236927  [  704/  750]
# train accuracy:		94.4%, train loss:		0.002867
# validation accuracy:	98.7%, validation loss:		0.001390
#
# Epoch 289
# -------------------------------
# loss: 0.254624  [   64/  750]
# loss: 0.133890  [  704/  750]
# train accuracy:		94.4%, train loss:		0.002681
# validation accuracy:	95.3%, validation loss:		0.002033
#
# Epoch 290
# -------------------------------
# loss: 0.262122  [   64/  750]
# loss: 0.254068  [  704/  750]
# train accuracy:		92.9%, train loss:		0.002958
# validation accuracy:	97.3%, validation loss:		0.001881
#
# Epoch 291
# -------------------------------
# loss: 0.163022  [   64/  750]
# loss: 0.145074  [  704/  750]
# train accuracy:		93.6%, train loss:		0.002973
# validation accuracy:	98.7%, validation loss:		0.001291
#
# Epoch 292
# -------------------------------
# loss: 0.141112  [   64/  750]
# loss: 0.176270  [  704/  750]
# train accuracy:		92.8%, train loss:		0.003193
# validation accuracy:	95.3%, validation loss:		0.002285
#
# Epoch 293
# -------------------------------
# loss: 0.165542  [   64/  750]
# loss: 0.204192  [  704/  750]
# train accuracy:		93.1%, train loss:		0.002970
# validation accuracy:	96.7%, validation loss:		0.001987
#
# Epoch 294
# -------------------------------
# loss: 0.197379  [   64/  750]
# loss: 0.155763  [  704/  750]
# train accuracy:		93.9%, train loss:		0.003168
# validation accuracy:	97.3%, validation loss:		0.001521
#
# Epoch 295
# -------------------------------
# loss: 0.066907  [   64/  750]
# loss: 0.088117  [  704/  750]
# train accuracy:		95.5%, train loss:		0.002678
# validation accuracy:	100.0%, validation loss:		0.001339
#
# Epoch 296
# -------------------------------
# loss: 0.158985  [   64/  750]
# loss: 0.293596  [  704/  750]
# train accuracy:		95.1%, train loss:		0.002449
# validation accuracy:	96.7%, validation loss:		0.001625
#
# Epoch 297
# -------------------------------
# loss: 0.223803  [   64/  750]
# loss: 0.134879  [  704/  750]
# train accuracy:		90.9%, train loss:		0.004036
# validation accuracy:	100.0%, validation loss:		0.001343
#
# Epoch 298
# -------------------------------
# loss: 0.133886  [   64/  750]
# loss: 0.249031  [  704/  750]
# train accuracy:		94.4%, train loss:		0.002916
# validation accuracy:	98.7%, validation loss:		0.001781
#
# Epoch 299
# -------------------------------
# loss: 0.150409  [   64/  750]
# loss: 0.222910  [  704/  750]
# train accuracy:		94.5%, train loss:		0.002628
# validation accuracy:	96.7%, validation loss:		0.001852
#
# Epoch 300
# -------------------------------
# loss: 0.211486  [   64/  750]
# loss: 0.248907  [  704/  750]
# train accuracy:		94.3%, train loss:		0.002767
# validation accuracy:	97.3%, validation loss:		0.001658
# Done!

# %%
plt.plot(np.arange(0,epochs),train_losses)
plt.plot(np.arange(0,epochs),validation_losses)
plt.title('Model  Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()

# %%
plt.plot(np.arange(0,epochs),train_acc)
plt.plot(np.arange(0,epochs),validation_acc)
plt.title('Model  Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()

# %%
test(dataloaders["test"], model, loss_fn)
# Out:
# test accuracy:		97.3%, test loss:		0.001658

# %%
test_acc, test_loss, cm = test_with_confusion(dataloaders["test"], model, loss_fn, class_names)
print(f"test accuracy: {(100*test_acc):>0.1f}%, test loss: {test_loss:>4f}")
print("Confusion Matrix:\n", cm)
# Out:
# test accuracy: 97.3%, test loss: 0.001658
# Confusion Matrix:
#  [[50  0  0]
#  [ 4 46  0]
#  [ 0  0 50]]

# %%
show_misclassified_images(dataloaders["test"], model, class_names, max_images=10)

# %%
path = r"data\test\Sc\Sc_1.bmp"
predict_class = predict_image(path, model, class_names)
print(f"The predicted classification is {predict_class}")
# Out:
# The predicted classification is Sc

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs

# %%
torch.save(model, 'model.pth')

# %%
model = torch.load('model.pth', weights_only=False)
